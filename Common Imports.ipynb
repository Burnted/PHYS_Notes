# %% [markdown]
# # Common Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import root, brentq, minimize
from scipy.interpolate import make_interp_spline, BarycentricInterpolator    
from scipy.integrate import quad

from numpy.polynomial.chebyshev import chebinterpolate, chebpts1, chebval, chebval2d, Chebyshev
