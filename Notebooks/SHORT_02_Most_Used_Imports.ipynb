# %% [markdown]
# # Short Notebook 2: Most Used Imports in Class Notes
#
# Computed from all 17 notebooks in `class notes`.

# %% [markdown]
# ## Most repeated import lines
# - `import numpy as np`
# - `import matplotlib.pyplot as plt`
# - `from scipy.integrate import solve_ivp`
# - `from scipy.optimize import root`
# - `import math`
# - `import pickle`
# - `from scipy.integrate import quad`
# - `from scipy.integrate import dblquad`
# - `from scipy.interpolate import RectBivariateSpline`
# - `from numpy import genfromtxt`
# - `import matplotlib as mpl`
# - `from numpy.polynomial import Polynomial as P`
# - `from scipy.integrate import dblquad, quad_vec`
# - `from scipy.constants import epsilon_0,pi #in SI units`
# - `import matplotlib.pyplot as plt #import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show`

# %% [markdown]
# ## Most used module roots
# - `scipy`
# - `numpy`
# - `matplotlib`
# - `math`
# - `pickle`
# - `timeit`
# - `time`
# - `multiprocessing`
# - `sys`

# %%
# Recommended baseline import block (adapt per notebook)
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp, quad
from scipy.optimize import root, root_scalar, minimize
from scipy.interpolate import interp1d, CubicSpline
